# %% [markdown]
# ## Text Classification - Natural Language Processing
#
# Text classification also known as *text tagging* or *text categorization* is the process of categorizing text into organized groups. By using Natural Language Processing (NLP), text classifiers can automatically analyze text and then assign a set of pre-defined tags or categories based on its content.
#
# This notebook aims to give  a brief overview of performing text classification using Naive Bayes, Logistic Regression, Support Vector Machines and Decision Tree Classifier. We will be using a dataset called "**Economic news article tone and relevance**" which consists of approximately 8000 news articles, which were tagged as ***relevant*** or ***not relevant*** to the US Economy. Our goal in this kernel is to explore the process of training and testing text classifiers for this dataset.

# %% [markdown]
# ![Text Classification](https://www.dataquest.io/wp-content/uploads/2019/04/text-classification-python-spacy.png)

# %% [markdown]
# ### Import Required Libraries

# %%
import numpy as np
import pandas as pd 

import matplotlib as mpl 
import matplotlib.cm as cm 
import matplotlib.pyplot as plt 
import plotly.graph_objects as go
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import _stop_words
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer 

import string
import re

from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

from sklearn.metrics import accuracy_score
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report
from sklearn import metrics

from time import time

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Analysis of Data

# %% [markdown]
# Reading data from csv file

# %%
data = pd.read_csv('data.csv', encoding = 'ISO-8859-1')
display(data.shape)
# Out:
# (8000, 15)

# %% [markdown]
# This code block is likely counting the frequency of each value in the "relevance" column of a DataFrame called "data".

# %%
data["relevance"].value_counts()
# Out:
# no          6571
# yes         1420
# not sure       9
# Name: relevance, dtype: int64

# %% [markdown]
# There is an imbalance in the data with not relevant being 82% in the dataset. That is, most of the articles are not relevant to US Economy, which makes sense in a real-world scenario, as news articles discuss various topics. We should keep this class imbalance mind when interpreting the classifier performance later. Let us first convert the class labels into binary outcome variables for convenience. 1 for Yes (relevant), and 0 for No (not relevant), and ignore "Not sure".

# %% [markdown]
# This code block filters out the rows in a dataframe data where the value in the "relevance" column is "not sure" and then returns the shape of the resulting dataframe.

# %%
data = data[data.relevance != "not sure"]
data.shape
# Out:
# (7991, 15)

# %% [markdown]
# This code block calculates the proportion of each value in the "relevance" column of a dataset. It divides the count of each value by the total number of rows in the dataset using the "shape" attribute.

# %%
data["relevance"].value_counts()/data.shape[0]
# Out:
# no     0.8223
# yes    0.1777
# Name: relevance, dtype: float64

# %% [markdown]
# This code block generates a horizontal bar plot using the plotly library, where the x-axis shows the categories of "relevance" and the y-axis shows the count of each category. The plot is given the title "Values in each Sentiment" and the x-axis label is "Sentiment" while the y-axis label is "Values". The resulting plot is displayed using the show() function.

# %%
fig = go.Figure([go.Bar(x=data['relevance'].value_counts().index, y=data['relevance'].value_counts().tolist())])
fig.update_layout(
    title="Values in each Sentiment",
    xaxis_title="Sentiment",
    yaxis_title="Values")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Text Pre-processing

# %% [markdown]
# This code block is performing the following actions:
#
# Converting the categorical labels in the relevance column from 'yes' and 'no' to 1 and 0 respectively, where 1 means the tweet is relevant and 0 means it is not relevant.
#
# Selecting only the text and relevance columns from the dataset.
#
# Limiting the number of rows in the dataset to 1000.
#
# Printing the shape of the dataset after performing the above operations.

# %%
data['relevance'] = data.relevance.map({'yes':1, 'no':0}) # relevant is 1, not-relevant is 0 
data = data[["text","relevance"]] # taking text input and output variable as relevance
data = data[:1000]
data.shape
# Out:
# (1000, 2)

# %%
data.head()
# Out:
#                                                 text  relevance
# 0  NEW YORK -- Yields on most certificates of dep...          1
# 1  The Wall Street Journal Online</br></br>The Mo...          0
# 2  WASHINGTON -- In an effort to achieve banking ...          0
# 3  The statistics on the enormous costs of employ...          0
# 4  NEW YORK -- Indecision marked the dollar's ton...          1

# %%
data['text'][0]
# Out:
# 'NEW YORK -- Yields on most certificates of deposit offered by major banks dropped more than a tenth of a percentage point in the latest week, reflecting the overall decline in short-term interest rates.</br></br>On small-denomination, or "consumer," CDs sold directly by banks, the average yield on six-month deposits fell to 5.49% from 5.62% in the week ended yesterday, according to an 18-bank survey by Banxquote Money Markets, a Wilmington, Del., information service.</br></br>On three-month "consumer" deposits, the average yield sank to 5.29% from 5.42% the week before, according to Banxquote. Two banks in the Banxquote survey, Citibank in New York and CoreStates in Pennsylvania, are paying less than 5% on threemonth small-denomination CDs.</br></br>Declines were somewhat smaller on five-year consumer CDs, which eased to 7.37% from 7.45%, Banxquote said.</br></br>Yields on three-month and six-month Treasury bills sold at Monday\'s auction plummeted more than a fifth of a percentage 
# ...

# %% [markdown]
# ### Text Cleaning

# %% [markdown]
# Typical steps involve tokenization, lower casing, removing, stop words, punctuation markers etc, and vectorization. Other processes such as stemming/lemmatization can also be performed. Here, we are performing the following steps: removing br tags, punctuation, numbers, and stopwords. While we are using sklearn's list of stopwords, there are several other stop word lists (e.g., from NLTK) or sometimes, custom stopword lists are needed depending on the task.

# %% [markdown]
# This code block defines a function clean() which takes a text input as a string and performs various preprocessing steps like converting to lowercase, removing stop words and punctuations, and lemmatizing the words. It also removes named entities from the text before performing the other preprocessing steps. The cleaned text is then returned as a string. The function uses the en_core_web_sm model of the spacy library for named entity recognition and WordNetLemmatizer from the nltk library for lemmatization.

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

stopwords = _stop_words.ENGLISH_STOP_WORDS
lemmatizer = WordNetLemmatizer()

def clean(doc):
    text_no_namedentities = []
    document = nlp(doc)
    ents = [e.text for e in document.ents]
    for item in document:
        if item.text in ents:
            pass
        else:
            text_no_namedentities.append(item.text)
    doc = (" ".join(text_no_namedentities))

    doc = doc.lower().strip()
    doc = doc.replace("</br>", " ") 
    doc = doc.replace("-", " ") 
    doc = "".join([char for char in doc if char not in string.punctuation and not char.isdigit()])
    doc = " ".join([token for token in doc.split() if token not in stopwords])    
    doc = "".join([lemmatizer.lemmatize(word) for word in doc])
    return doc

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
clean(data['text'][0])
# Out:
# 'new york yields certificates deposit offered major banks dropped tenth percentage point latest week reflecting overall decline short term rates br small denomination consumer cds sold directly banks average yield month deposits fell week ended yesterday according bank survey money markets information service br month consumer deposits average yield sank week according banks survey new york paying small denomination declines somewhat smaller year consumer cds eased said br yields month month bills sold s auction plummeted fifth percentage point previous week respectively'

# %%
data['text'] = data['text'].apply(clean)
data.head()
# Out:
#                                                 text  relevance
# 0  new york yields certificates deposit offered m...          1
# 1  wall street journal online br morning brief lo...          0
# 2  effort achieve banking reform negotiators admi...          0
# 3  statistics enormous costs employee drug abuse ...          0
# 4  new york indecision marked dollar s tone trade...          1

# %% [markdown]
# Now we are ready for the modeling. We are going to use algorithms from sklearn package. We will go through the following steps:
#
# 1. Split the data into training and test sets (80% train, 20% test)
# 2. Extract features from the training data using TfidfVectorizer.
# 3. Transform the test data into the same feature vector as the training data.
# 4. Train the classifier
# 5. Evaluate the classifier

# %% [markdown]
# ## TF-IDF Vectorizer
#
# ![TF-IDF](https://miro.medium.com/max/3136/1*ruCawEw0--m2SeHmAQooJQ.jpeg)

# %% [markdown]
# This code block converts the text data into a numerical representation using the TfidfVectorizer from scikit-learn. The TfidfVectorizer converts the raw text data into a matrix of TF-IDF features. The resulting matrix is stored in tfidf_vectorizer_vectors, and the array representation is stored in docs.

# %%
docs = list(data['text'])
tfidf_vectorizer = TfidfVectorizer(use_idf=True, max_features = 20000) 
tfidf_vectorizer_vectors = tfidf_vectorizer.fit_transform(docs)
docs = tfidf_vectorizer_vectors.toarray()

# %% [markdown]
# This code block defines the input feature matrix X and target variable vector y for a classification task. X is a matrix of shape (n_samples, n_features) representing the TF-IDF vectorized text data, where n_samples is the number of documents and n_features is the number of features extracted. y is a vector of shape (n_samples,) representing the binary target variable, where 1 denotes relevant and 0 denotes not relevant. The shape of X and y are printed to the console.

# %%
X = docs 
y = data['relevance']
print(X.shape, y.shape)
# Out:
# (1000, 12523) (1000,)

# %% [markdown]
# This code block generates a bar chart using the plotly library to show the number of occurrences of each value in the relevance column of the data dataframe.

# %%
fig = go.Figure([go.Bar(x=y.value_counts().index, y=y.value_counts().tolist())])
fig.update_layout(
    title="Values in each Sentiment",
    xaxis_title="Sentiment",
    yaxis_title="Values")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Train-Test Split

# %% [markdown]
# This code block performs train-test split on the feature matrix X and target vector y using train_test_split() function from Scikit-learn library. The size of the test set is set to be 20% of the data and the random state is fixed to SEED for reproducibility. The stratify parameter is used to ensure that the proportion of classes in the training and test set is the same as that of the original dataset. The code prints the shape of training and test sets.

# %%
SEED=123
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.2, random_state=SEED, stratify=y)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (800, 12523) (800,)
# (200, 12523) (200,)

# %% [markdown]
# ## Naive Bayes Classifier

# %% [markdown]
# ### Gaussian Naive Bayes

# %% [markdown]
# This code block fits a Gaussian Naive Bayes model to the training data, predicts the classes for the training and testing data, and then prints out the accuracy scores for the training and testing sets. The training set is also used to time the fitting of the model.

# %%
gnb = GaussianNB() 
# %time gnb.fit(X_train, y_train)

y_pred_train = gnb.predict(X_train)
y_pred_test = gnb.predict(X_test)
print("\nTraining Accuracy score:",accuracy_score(y_train, y_pred_train))
print("Testing Accuracy score:",accuracy_score(y_test, y_pred_test))
# Out:
# CPU times: user 75.7 ms, sys: 40.1 ms, total: 116 ms
# Wall time: 120 ms
#
# Training Accuracy score: 0.9975
# Testing Accuracy score: 0.765

# %%
print(classification_report(y_test, y_pred_test, target_names=['not relevant', 'relevant']))
# Out:
#               precision    recall  f1-score   support
#
# not relevant       0.77      0.99      0.86       151
#     relevant       0.67      0.08      0.15        49
#
#     accuracy                           0.77       200
#    macro avg       0.72      0.53      0.50       200
# weighted avg       0.74      0.77      0.69       200

# %% [markdown]
# calculate the confusion matrix

# %%
cm = confusion_matrix(y_test, y_pred_test)
# print('Confusion matrix\n', cm)

cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive', 'Actual Negative'], 
                        index=['Predict Positive', 'Predict Negative'])
sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
plt.show()

# %% [markdown]
# This code block generates the Receiver Operating Characteristic (ROC) curve for the Gaussian Naive Bayes classifier. It first calculates the predicted probabilities for the test set using the predict_proba() method of the classifier, then extracts the predicted probabilities for the positive class (preds) and calculates the false positive rate (fpr) and true positive rate (tpr) using the roc_curve() function from the sklearn.metrics library. Finally, it plots the ROC curve and computes the area under the curve (AUC).

# %%
probs = gnb.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# Gaussian Naive Bayes performs poorly in this case because of the prior and posterior probability condition

# %% [markdown]
# ### Multinomial Naive Bayes

# %% [markdown]
# Training Multinomial NB model

# %%
mnb = MultinomialNB() 
# %time mnb.fit(X_train, y_train)

y_pred_train = mnb.predict(X_train)
y_pred_test = mnb.predict(X_test)
print("\nTraining Accuracy score:",accuracy_score(y_train, y_pred_train))
print("Testing Accuracy score:",accuracy_score(y_test, y_pred_test))
# Out:
# CPU times: user 47.9 ms, sys: 14 ms, total: 61.9 ms
# Wall time: 53.6 ms
#
# Training Accuracy score: 0.7575
# Testing Accuracy score: 0.755

# %%
print(classification_report(y_test, y_pred_test, target_names=['not relevant', 'relevant']))
# Out:
#               precision    recall  f1-score   support
#
# not relevant       0.76      1.00      0.86       151
#     relevant       0.00      0.00      0.00        49
#
#     accuracy                           0.76       200
#    macro avg       0.38      0.50      0.43       200
# weighted avg       0.57      0.76      0.65       200

# %% [markdown]
# Calculating the confusion matrix

# %%
cm = confusion_matrix(y_test, y_pred_test)
# print('Confusion matrix\n', cm)

cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive', 'Actual Negative'], 
                        index=['Predict Positive', 'Predict Negative'])
sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
plt.show()

# %% [markdown]
# This code block generates the Receiver Operating Characteristic (ROC) curve for the Gaussian Naive Bayes classifier. It first calculates the predicted probabilities for the test set using the predict_proba() method of the classifier, then extracts the predicted probabilities for the positive class (preds) and calculates the false positive rate (fpr) and true positive rate (tpr) using the roc_curve() function from the sklearn.metrics library. Finally, it plots the ROC curve and computes the area under the curve (AUC).

# %%
probs = mnb.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# Multinomial Naive Bayes performs slightly better than Gaussian Naive Bayes, but the low AUC score is because the size of feature vector is really big and Bayes Algorothm works better for small number of features. Let's check out results of Logistic Regression, Support Vector Machines and Decision Tree Classifier.

# %% [markdown]
# ## Logistic Regression Classifier

# %% [markdown]
# Training Logistic Regression model

# %%
lr = LogisticRegression(random_state=SEED)
# %time lr.fit(X_train, y_train)

y_pred_train = lr.predict(X_train)
y_pred_test = lr.predict(X_test)
print("\nTraining Accuracy score:",accuracy_score(y_train, y_pred_train))
print("Testing Accuracy score:",accuracy_score(y_test, y_pred_test))
# Out:
# CPU times: user 572 ms, sys: 395 ms, total: 966 ms
# Wall time: 841 ms
#
# Training Accuracy score: 0.81375
# Testing Accuracy score: 0.765

# %% [markdown]
# Calculating the confusion matrix

# %%
cm = confusion_matrix(y_test, y_pred_test)
#print('Confusion matrix\n', cm)

cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive', 'Actual Negative'], 
                        index=['Predict Positive', 'Predict Negative'])
sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
plt.show()

# %%
print(classification_report(y_test, y_pred_test, target_names=['not relevant', 'relevant']))
# Out:
#               precision    recall  f1-score   support
#
# not relevant       0.77      0.99      0.86       151
#     relevant       0.67      0.08      0.15        49
#
#     accuracy                           0.77       200
#    macro avg       0.72      0.53      0.50       200
# weighted avg       0.74      0.77      0.69       200

# %% [markdown]
# This code block generates the Receiver Operating Characteristic (ROC) curve for the Gaussian Naive Bayes classifier. It first calculates the predicted probabilities for the test set using the predict_proba() method of the classifier, then extracts the predicted probabilities for the positive class (preds) and calculates the false positive rate (fpr) and true positive rate (tpr) using the roc_curve() function from the sklearn.metrics library. Finally, it plots the ROC curve and computes the area under the curve (AUC).

# %%
probs = lr.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## Support Vector Machines

# %%
svc =  LinearSVC(class_weight='balanced') 
# %time svc.fit(X_train, y_train)

y_pred_train = svc.predict(X_train)
y_pred_test = svc.predict(X_test)
print("\nTraining Accuracy score:",accuracy_score(y_train, y_pred_train))
print("Testing Accuracy score:",accuracy_score(y_test, y_pred_test))
# Out:
# CPU times: user 47.7 ms, sys: 0 ns, total: 47.7 ms
# Wall time: 50.5 ms
#
# Training Accuracy score: 1.0
# Testing Accuracy score: 0.75

# %% [markdown]
# Calculating the confusion matrix

# %%
cm = confusion_matrix(y_test, y_pred_test)
# print('Confusion matrix\n', cm)

cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive', 'Actual Negative'], 
                        index=['Predict Positive', 'Predict Negative'])
sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
plt.show()

# %%
print(classification_report(y_test, y_pred_test, target_names=['not relevant', 'relevant']))
# Out:
#               precision    recall  f1-score   support
#
# not relevant       0.82      0.85      0.84       151
#     relevant       0.49      0.43      0.46        49
#
#     accuracy                           0.75       200
#    macro avg       0.66      0.64      0.65       200
# weighted avg       0.74      0.75      0.74       200

# %% [markdown]
# This code block generates the Receiver Operating Characteristic (ROC) curve for the Gaussian Naive Bayes classifier. It first calculates the predicted probabilities for the test set using the predict_proba() method of the classifier, then extracts the predicted probabilities for the positive class (preds) and calculates the false positive rate (fpr) and true positive rate (tpr) using the roc_curve() function from the sklearn.metrics library. Finally, it plots the ROC curve and computes the area under the curve (AUC).

# %%
probs = svc._predict_proba_lr(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=SEED)
# %time dt.fit(X_train, y_train)

y_pred_train = dt.predict(X_train)
y_pred_test = dt.predict(X_test)
print("\nTraining Accuracy score:",accuracy_score(y_train, y_pred_train))
print("Testing Accuracy score:",accuracy_score(y_test, y_pred_test))
# Out:
# CPU times: user 861 ms, sys: 9.85 ms, total: 871 ms
# Wall time: 864 ms
#
# Training Accuracy score: 1.0
# Testing Accuracy score: 0.71

# %% [markdown]
# Calculating the confusion matrix

# %%
cm = confusion_matrix(y_test, y_pred_test)
# print('Confusion matrix\n', cm)

cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive', 'Actual Negative'], 
                        index=['Predict Positive', 'Predict Negative'])
sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
plt.show()

# %%
print(classification_report(y_test, y_pred_test, target_names=['not relevant', 'relevant']))
# Out:
#               precision    recall  f1-score   support
#
# not relevant       0.80      0.82      0.81       151
#     relevant       0.40      0.37      0.38        49
#
#     accuracy                           0.71       200
#    macro avg       0.60      0.59      0.60       200
# weighted avg       0.70      0.71      0.71       200

# %% [markdown]
# ## Ensembling

# %% [markdown]
# This code block creates a Voting Classifier using three different classifiers - Decision Tree, Logistic Regression, and Naive Bayes. It then fits the Voting Classifier to the training set and predicts test set labels. Finally, it prints the training and testing accuracy scores.

# %%
from sklearn.ensemble import VotingClassifier

classifiers = [('Decision Tree', dt),
               ('Logistic Regression', lr),
                ('Naive Bayes', gnb)
              ]
vc = VotingClassifier(estimators=classifiers)
# Fit 'vc' to the traing set and predict test set labels
vc.fit(X_train, y_train)
y_pred_train=vc.predict(X_train)
y_pred_test = vc.predict(X_test)
print("Training Accuracy score:",accuracy_score(y_train, y_pred_train))
print("Testing Accuracy score:",accuracy_score(y_test, y_pred_test))
# Out:
# Training Accuracy score: 1.0
# Testing Accuracy score: 0.77

# %% [markdown]
# This code block generates predictions using the trained Voting Classifier model on the entire dataset and saves the results to a CSV file named "us-economic-news-relevance.csv".

# %%
predictions = pd.Series(vc.predict(X), name="relevant")
results = pd.concat([predictions],axis=1)
results.to_csv("us-economic-news-relevance.csv",index=False)

# %% [markdown]
# So, how do we choose whats the best? If we look at overall accuracy alone, we should be choosing the very first classifier in this notebook. However, that is also doing poorly with identifying "relevant" articles. If we choose purely based on how good it is doing with "relevant" category, we should choose the second one we built. If we choose purely based on how good it is doing with "irrelevant" category, surely, nothing beats not building any classifier and just calling everything irrelevant! So, what to choose as the best among these depends on what we are looking for in our usecase!
